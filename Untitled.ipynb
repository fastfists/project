# %% [markdown]
# # Simple Regressions

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("bigPoppa.csv")

# %%
data
# Out:
#       easting  northing  porosity  permeability  Poisson's ratio  \
# 0     67000.0    2400.0      0.08         0.028            0.326
# 1     67079.0    2400.0      0.07         0.025            0.326
# 2     67157.0    2400.0      0.10         0.044            0.326
# 3     67236.0    2400.0      0.10         0.044            0.326
# 4     67314.0    2400.0      0.08         0.029            0.326
# ...       ...       ...       ...           ...              ...
# 9995  15876.0   53700.0      0.02         0.001            0.301
# 9996  15977.0   53700.0      0.01         0.000            0.301
# 9997  16077.0   53700.0      0.03         0.004            0.301
# 9998  16178.0   53700.0      0.04         0.005            0.301
# 9999  16279.0   53700.0      0.01         0.000            0.301
#
#       Young's Modulus  water saturation  oil saturation  \
# 0        1.017070e+07          0.133937        0.866063
# 1        1.015911e+07          0.134879        0.865121
# 2        1.014748e+07          0.135815        0.864185
# 3        1.014748e+07          0.135815        0.864185
# 4        1.013582e+07          0.136746        0.863254
# ...               ...               ...             ...
# 9995     1.116138e+07          0.112799        0.887201
# 9996     1.117023e+07          0.112979        0.887021
# 9997     1.117912e+07          0.113159        0.886841
# 9998     1.118806e+07          0.113341        0.886659
# 9999     1.119705e+07          0.113523        0.886477
#
#       proppant weight (lbs)  pump rate (cubic feet/min)              Name  \
# 0              6.636119e+05                  217.392979        Peak 9-46H
# 1                       NaN                         NaN        Peak 9-46H
# 2              6.478595e+05                  364.317211        Peak 9-46H
# 3                       NaN                         NaN        Peak 9-46H
# 4              5.511870e+05                  359.263441        Peak 9-46H
# ...                     ...                         ...               ...
# 9995                    NaN                         NaN  Sutherland 5-56H
# 9996           1.001242e+06                  292.311608  Sutherland 5-56H
# 9997                    NaN                         NaN  Sutherland 5-56H
# 9998                    NaN                         NaN  Sutherland 5-56H
# 9999           7.815088e+05                  293.346528  Sutherland 5-56H
#
#       lifetime_exp  lifetime_hyp  cum_production  well length  frac stages
# 0        52.483608     52.484055   157593.221982       7782.0           50
# 1        52.483608     52.484055   157593.221982       7782.0           50
# 2        52.483608     52.484055   157593.221982       7782.0           50
# 3        52.483608     52.484055   157593.221982       7782.0           50
# 4        52.483608     52.484055   157593.221982       7782.0           50
# ...            ...           ...             ...          ...          ...
# 9995     27.755301     27.755386    11798.147622       9979.0           34
# 9996     27.755301     27.755386    11798.147622       9979.0           34
# 9997     27.755301     27.755386    11798.147622       9979.0           34
# 9998     27.755301     27.755386    11798.147622       9979.0           34
# 9999     27.755301     27.755386    11798.147622       9979.0           34
#
# [10000 rows x 16 columns]

# %% [markdown]
# # Graphing all well locations

# %%
sns.scatterplot(data["easting"], data["northing"])
plt.ylabel("Northing")
plt.xlabel("Easting")
plt.title("Location of Horizontal wells, starting position")
# Out:
# /home/fastfist/devel/anaconda3/envs/energyanalytics/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Location of Horizontal wells, starting position')
